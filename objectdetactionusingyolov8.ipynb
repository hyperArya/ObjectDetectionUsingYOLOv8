# %% [markdown]
# <a href="https://colab.research.google.com/github/hyperArya/ObjectDetectionUsingYOLOv8/blob/main/objectdetactionusingyolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.0/755.0 kB 9.8 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Use the model
model.train(data="coco8.yaml", epochs=50)  # train the model
metrics = model.val()  # evaluate model performance on the validation set
results = model("https://ultralytics.com/images/bus.jpg")  # predict on an image
path = model.export(format="onnx")  # export the model to ONNX format
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 86.8MB/s]
# Ultralytics YOLOv8.2.5 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# Load a YOLO model (replace "path/to/your/best.pt" with the actual model path)
model = YOLO("/content/runs/detect/train/weights/best.onnx")

# Perform inference on an image from a URL
results = model("https://static.javatpoint.com/python/images/object-recognition-using-python.jpg")

# Get the first result (assuming there's only one image)
result = results[0]

# Plot the results with bounding boxes and other information
result.plot()  # This will draw the bounding boxes, labels, and confidences

# Show the image with marked results in a Jupyter/Colab environment
plt.imshow(result.plot(show=False))  # plot() returns an image with bounding boxes
plt.axis('off')  # Hide axes
plt.title("YOLO Detection Results")
plt.show()
# Out:
# Loading /content/runs/detect/train/weights/best.onnx for ONNX Runtime inference...
#
# Found https://static.javatpoint.com/python/images/object-recognition-using-python.jpg locally at object-recognition-using-python.jpg
# image 1/1 /content/object-recognition-using-python.jpg: 640x640 22 persons, 15 cars, 1 bus, 3 trucks, 166.2ms
# Speed: 3.5ms preprocess, 166.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
